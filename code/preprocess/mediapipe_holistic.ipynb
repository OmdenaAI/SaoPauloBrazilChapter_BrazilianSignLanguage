# %% [markdown]
# # MediaPipe

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import glob
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import seaborn as sns

import vizualisation as viz
import mediapipe_holistic as mh

# %%
# change working directory to the project root directory
current_dir = os.getcwd()
os.chdir(current_dir + '/../../')
# this should be the project root directory
os.getcwd()
# Out:
# '/Users/gustavosantos/code/omdena/SaoPauloBrazilChapter_BrazilianSignLanguage'

# %% [markdown]
# ## Information

# %% [markdown]
# ### MediaPipe Holistic
# #### [DOCS](https://github.com/google-ai-edge/mediapipe/blob/master/docs/solutions/holistic.md)
#
# MediaPipe Holistic utilizes the pose, face and hand landmark models in [MediaPipe Pose](https://github.com/google-ai-edge/mediapipe/blob/master/docs/solutions/pose.md), [MediaPipe Face Mesh](https://github.com/google-ai-edge/mediapipe/blob/master/docs/solutions/face_mesh.md) and [MediaPipe Hands](https://github.com/google-ai-edge/mediapipe/blob/master/docs/solutions/hands.md) respectively to generate a total of 543 landmarks (33 pose landmarks, 468 face landmarks, and 21 hand landmarks per hand).
#
# **INPUT**
#
# 480x480
#
# **Output**
#
# Naming style may differ slightly across platforms/languages.
#
# **pose_landmarks**
#
# A list of pose landmarks. Each landmark consists of the following:
#
# - `x` and `y`: Landmark coordinates normalized to `[0.0, 1.0]` by the image width and height respectively.
# - `z`: Should be discarded as currently the model is not fully trained to predict depth, but this is something on the roadmap.
# - `visibility`: A value in `[0.0, 1.0]` indicating the likelihood of the landmark being visible (present and not occluded) in the image.
#
# **pose_world_landmarks**
#
# Another list of pose landmarks in world coordinates. Each landmark consists of the following:
#
# - `x`, `y` and `z`: Real-world 3D coordinates in meters with the origin at the center between hips.
# - `visibility`: Identical to that defined in the corresponding [pose_landmarks](https://github.com/google-ai-edge/mediapipe/blob/master/docs/solutions/holistic.md#pose_landmarks).
#
# **face_landmarks**
#
# A list of 468 face landmarks. Each landmark consists of `x`, `y` and `z`. `x` and `y` are normalized to `[0.0, 1.0]` by the image width and height respectively. `z` represents the landmark depth with the depth at center of the head being the origin, and the smaller the value the closer the landmark is to the camera. The magnitude of `z` uses roughly the same scale as `x`.
#
# **left_hand_landmarks**
#
# A list of 21 hand landmarks on the left hand. Each landmark consists of `x`, `y` and `z`. `x` and `y` are normalized to `[0.0, 1.0]` by the image width and height respectively. `z` represents the landmark depth with the depth at the wrist being the origin, and the smaller the value the closer the landmark is to the camera. The magnitude of `z` uses roughly the same scale as `x`.
#
# **right_hand_landmarks**
#
# A list of 21 hand landmarks on the right hand, in the same representation as [left_hand_landmarks](https://github.com/google-ai-edge/mediapipe/blob/master/docs/solutions/holistic.md#left_hand_landmarks).
#
# **segmentation_mask**
#
# The output segmentation mask, predicted only when [enable_segmentation](https://github.com/google-ai-edge/mediapipe/blob/master/docs/solutions/holistic.md#enable_segmentation) is set to `true`. The mask has the same width and height as the input image, and contains values in `[0.0, 1.0]` where `1.0` and `0.0` indicate high certainty of a "human" and "background" pixel respectively. Please refer to the platform-specific usage examples below for usage details.

# %% [markdown]
# ## Load Video Metadata

# %%
video_metadata_df = pd.read_csv('data/raw/combined/target_dataset_video_metadata.csv')

# %%
def get_frame(frame_index, video_path):
    cap = cv2.VideoCapture(video_path)
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_index)  # Set frame index
    ret, frame = cap.read()
    cap.release()
    if not ret:
        print(f"Could not read frame {frame_index} from video")
        frame = None
    return frame

# %% [markdown]
# ## Holistic Model

# %% [markdown]
# ### Detect

# %%
i = 1
row = video_metadata_df.iloc[i]
video_path = f"data/raw/combined/videos/{row.filename}"
video_path
# Out:
# 'data/raw/combined/videos/ajudar_sb_2.mp4'

# %%
# Initialize detector
mediapipe = mh.MediaPipeHolistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5,
    model_complexity=1,  # 0=Lite, 1=Full, 2=Heavy
    refine_face_landmarks=True
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1744222053.140679 2001253 gl_context.cc:369] GL version: 2.1 (2.1 INTEL-20.7.3), renderer: Intel(R) Iris(TM) Plus Graphics 650
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
landmarks = mediapipe.process_video(video_path)
# Out:
# W0000 00:00:1744222053.680350 2001452 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744222053.734411 2001449 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744222053.742987 2001452 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744222053.743229 2001451 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744222053.743628 2001449 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744222053.772531 2001450 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# W0000 00:00:1744222053.780510 2001451 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744222053.780510 2001449 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744222053.783301 2001452 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %% [markdown]
# ### Visualize

# %%
frame_index = 10
frame = get_frame(frame_index, video_path)

# %% [markdown]
# See landmarks on a square canvas

# %%
viz_mediapipe = viz.MediaPipeHolistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5,
    model_complexity=1,  # 0=Lite, 1=Full, 2=Heavy
    refine_face_landmarks=True
)
# Out:
# I0000 00:00:1744222059.761126 2001253 gl_context.cc:369] GL version: 2.1 (2.1 INTEL-20.7.3), renderer: Intel(R) Iris(TM) Plus Graphics 650

# %%
skeleton = viz_mediapipe.draw_landmarks_on_frame(np.zeros((1000,1000,3), dtype=np.uint8), landmarks[frame_index])
plt.imshow(skeleton[:,:,::-1])
# Out:
# W0000 00:00:1744222060.353568 2001555 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744222060.447449 2001554 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744222060.461057 2001554 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744222060.470885 2001557 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744222060.624724 2001555 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744222060.642526 2001556 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744222060.673454 2001555 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744222060.814271 2001554 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %% [markdown]
# See landmarks drawn on their respective frame

# %%
annotated_frame = viz_mediapipe.draw_landmarks_on_frame(frame, landmarks[frame_index])
plt.imshow(annotated_frame[:,:,::-1])

# %% [markdown]
# Save a video with landmarks drawn on each frame

# %%
viz_mediapipe.draw_landmarks_on_video(video_path, landmarks, 'mediapipe_landmarks_example.mp4')
# Out:
# Landmarks drawn video saved to mediapipe_landmarks_example.mp4

# %% [markdown]
# 3D Plot, showing that landmarks are also detected in 3D space

# %%
fig = viz_mediapipe.draw_landmarks_3d(
    landmarks[frame_index],
    figsize=(5, 5),
    elev=25,     # Look slightly from above
    azim=45,     # Look from the front
    xlim=(-1,1),
    ylim=(-.5,.5),
    zlim=(-.5,.5)
)
plt.show()

# %% [markdown]
# ## Post Process

# %% [markdown]
# ### Horizontal Alignment

# %% [markdown]
# We know the horizontal center should be 0.5, so we can use center the signer horizontally.
#
# There are some ways we can find the mid point of the signer. To find the best, we developed these different types:
#
# - Nose tip: This uses the node that refers to the nose tip on the face landmark mask
# - Mean point: This computes the mid point between the top of the head and the chin
# - Pupils: This uses the mid point between the persons pupils to define the center of the face horizontally
# - Cheeks: uses the mid point between the checkbones
# - Ears: uses the mid point between the ears

# %% [markdown]
# #### Nose tip

# %%
horizontal_offsets = mediapipe.get_video_horizontal_offsets(landmarks, face_ref="nose_tip")
horizontal_offsets
# Out:
# {'shoulders': {'mean': 0.49492761907698235,
#   'median': 0.4965530186891556,
#   'max': 0.5088723599910736,
#   'min': 0.4815453886985779},
#  'face': {'mean': 0.49352897609336466,
#   'median': 0.49641475081443787,
#   'max': 0.5097975134849548,
#   'min': 0.47643986344337463}}

# %%
horizontal_offset = 0.5 - (horizontal_offsets['shoulders']['median'] + horizontal_offsets['face']['median'])/2
horizontal_offset
# Out:
# 0.0035161152482032776

# %%
annotated_frame = viz_mediapipe.draw_landmarks_on_frame(frame, landmarks[frame_index])
plt.imshow(annotated_frame[:,:,::-1])

# %%
horizontal_aligned_landmarks = mediapipe.shift_landmarks_series_horizontally(landmarks, horizontal_offset)

# %%
annotated_frame = viz_mediapipe.draw_landmarks_on_frame(frame, horizontal_aligned_landmarks[frame_index])
plt.imshow(annotated_frame[:,:,::-1])

# %%
frame.shape[1]*horizontal_offset
horizontal_aligned_frame = np.hstack((frame[:,75:,:], frame[:,:75,:]))

# %%
annotated_frame = viz_mediapipe.draw_landmarks_on_frame(horizontal_aligned_frame, horizontal_aligned_landmarks[frame_index])
plt.imshow(annotated_frame[:,:,::-1])

# %% [markdown]
# #### Mean point

# %%
horizontal_offsets_mean_point = mediapipe.get_video_horizontal_offsets(landmarks, face_ref="mean_point")
horizontal_offsets_mean_point
# Out:
# {'shoulders': {'mean': 0.49492761907698235,
#   'median': 0.4965530186891556,
#   'max': 0.5088723599910736,
#   'min': 0.4815453886985779},
#  'face': {'mean': 0.4923242106090618,
#   'median': 0.4960126280784607,
#   'max': 0.5078698396682739,
#   'min': 0.47463832795619965}}

# %%
horizontal_offset_mean_point = 0.5 - (horizontal_offsets_mean_point['shoulders']['median'] + horizontal_offsets_mean_point['face']['median'])/2
horizontal_offset_mean_point
# Out:
# 0.003717176616191864

# %%
annotated_frame = viz_mediapipe.draw_landmarks_on_frame(frame, landmarks[frame_index])
plt.imshow(annotated_frame[:,:,::-1])

# %%
horizontal_aligned_landmarks = mediapipe.shift_landmarks_series_horizontally(landmarks, horizontal_offset_mean_point)

# %%
annotated_frame = viz_mediapipe.draw_landmarks_on_frame(frame, horizontal_aligned_landmarks[frame_index])
plt.imshow(annotated_frame[:,:,::-1])

# %%
frame.shape[1]*horizontal_offset_mean_point
horizontal_aligned_frame = np.hstack((frame[:,75:,:], frame[:,:75,:]))

# %%
annotated_frame = viz_mediapipe.draw_landmarks_on_frame(horizontal_aligned_frame, horizontal_aligned_landmarks[frame_index])
plt.imshow(annotated_frame[:,:,::-1])

# %% [markdown]
# #### Pupils

# %%
horizontal_offsets_pupils = mediapipe.get_video_horizontal_offsets(landmarks, face_ref="pupils")
horizontal_offsets_pupils
# Out:
# {'shoulders': {'mean': 0.49492761907698235,
#   'median': 0.4965530186891556,
#   'max': 0.5088723599910736,
#   'min': 0.4815453886985779},
#  'face': {'mean': 0.4888248918931695,
#   'median': 0.493473619222641,
#   'max': 0.5040923207998276,
#   'min': 0.4684883952140808}}

# %%
horizontal_offset_pupils = 0.5 - (horizontal_offsets_pupils['shoulders']['median'] + horizontal_offsets_pupils['face']['median'])/2
horizontal_offset_pupils
# Out:
# 0.004986681044101715

# %%
annotated_frame = viz_mediapipe.draw_landmarks_on_frame(frame, landmarks[frame_index])
plt.imshow(annotated_frame[:,:,::-1])

# %%
horizontal_aligned_landmarks = mediapipe.shift_landmarks_series_horizontally(landmarks, horizontal_offset_pupils)

# %%
annotated_frame = viz_mediapipe.draw_landmarks_on_frame(frame, horizontal_aligned_landmarks[frame_index])
plt.imshow(annotated_frame[:,:,::-1])

# %%
frame.shape[1]*horizontal_offset_pupils
horizontal_aligned_frame = np.hstack((frame[:,75:,:], frame[:,:75,:]))

# %%
annotated_frame = viz_mediapipe.draw_landmarks_on_frame(horizontal_aligned_frame, horizontal_aligned_landmarks[frame_index])
plt.imshow(annotated_frame[:,:,::-1])

# %% [markdown]
# #### Cheekbones

# %%
horizontal_offsets_cheek = mediapipe.get_video_horizontal_offsets(landmarks, face_ref="cheeks")
horizontal_offsets_cheek
# Out:
# {'shoulders': {'mean': 0.49492761907698235,
#   'median': 0.4965530186891556,
#   'max': 0.5088723599910736,
#   'min': 0.4815453886985779},
#  'face': {'mean': 0.48633371312407,
#   'median': 0.48911726474761963,
#   'max': 0.503702774643898,
#   'min': 0.46527640521526337}}

# %%
horizontal_offset_cheek = 0.5 - (horizontal_offsets_cheek['shoulders']['median'] + horizontal_offsets_cheek['face']['median'])/2
horizontal_offset_cheek
# Out:
# 0.007164858281612396

# %%
annotated_frame = viz_mediapipe.draw_landmarks_on_frame(frame, landmarks[frame_index])
plt.imshow(annotated_frame[:,:,::-1])

# %%
horizontal_aligned_landmarks = mediapipe.shift_landmarks_series_horizontally(landmarks, horizontal_offset_cheek)

# %%
annotated_frame = viz_mediapipe.draw_landmarks_on_frame(frame, horizontal_aligned_landmarks[frame_index])
plt.imshow(annotated_frame[:,:,::-1])

# %%
frame.shape[1]*horizontal_offset_cheek
horizontal_aligned_frame = np.hstack((frame[:,75:,:], frame[:,:75,:]))

# %%
annotated_frame = viz_mediapipe.draw_landmarks_on_frame(horizontal_aligned_frame, horizontal_aligned_landmarks[frame_index])
plt.imshow(annotated_frame[:,:,::-1])

# %% [markdown]
# #### Ears

# %%
horizontal_offsets_ear = mediapipe.get_video_horizontal_offsets(landmarks, face_ref="nose_tip")
horizontal_offsets_ear
# Out:
# {'shoulders': {'mean': 0.49492761907698235,
#   'median': 0.4965530186891556,
#   'max': 0.5088723599910736,
#   'min': 0.4815453886985779},
#  'face': {'mean': 0.49352897609336466,
#   'median': 0.49641475081443787,
#   'max': 0.5097975134849548,
#   'min': 0.47643986344337463}}

# %%
horizontal_offset_ear = 0.5 - (horizontal_offsets_ear['shoulders']['median'] + horizontal_offsets_ear['face']['median'])/2
horizontal_offset_ear
# Out:
# 0.0035161152482032776

# %%
annotated_frame = viz_mediapipe.draw_landmarks_on_frame(frame, landmarks[frame_index])
plt.imshow(annotated_frame[:,:,::-1])

# %%
horizontal_aligned_landmarks = mediapipe.shift_landmarks_series_horizontally(landmarks, horizontal_offset_ear)

# %%
annotated_frame = viz_mediapipe.draw_landmarks_on_frame(frame, horizontal_aligned_landmarks[frame_index])
plt.imshow(annotated_frame[:,:,::-1])

# %%
frame.shape[1]*horizontal_offset_ear
horizontal_aligned_frame = np.hstack((frame[:,75:,:], frame[:,:75,:]))

# %%
annotated_frame = viz_mediapipe.draw_landmarks_on_frame(horizontal_aligned_frame, horizontal_aligned_landmarks[frame_index])
plt.imshow(annotated_frame[:,:,::-1])

# %% [markdown]
# ### Scaling

# %%
measurements = mediapipe.get_video_landmark_measurements(landmarks)
pd.DataFrame(measurements).T
# Out:
#                            mean    median       max
# shoulder_width         0.180338  0.172927  0.200056
# hip_width              0.122342  0.122392  0.127677
# shoulder_to_hip        0.471220  0.468286  0.501800
# left_arm_length        0.309800  0.284318  0.396285
# right_arm_length       0.183952  0.131146  0.403019
# face_width             0.085532  0.085351  0.087712
# face_height            0.186483  0.185882  0.192367
# top_head_to_shoulders  0.265184  0.260974  0.311634
# nose_to_shoulders      0.182391  0.180683  0.237984
# chin_to_shoulders      0.078847  0.071868  0.126097

# %% [markdown]
# #### Vertical Alignment
